# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.622407
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 2.243244
# Minibatch accuracy: 6.2%
# Validation accuracy: 26.1%
# Minibatch loss at step 100: 1.294163
# Minibatch accuracy: 50.0%
# Validation accuracy: 57.3%
# Minibatch loss at step 150: 0.603716
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.0%
# Minibatch loss at step 200: 0.917434
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 250: 1.427707
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 300: 0.339173
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 350: 0.598510
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.4%
# Minibatch loss at step 400: 0.310326
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 450: 0.912930
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 500: 0.712825
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 550: 0.911601
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 600: 0.364427
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.954275
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 1.104737
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.070437
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 800: 0.678378
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.938534
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 900: 0.741872
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 950: 0.521518
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.461373
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Test accuracy: 89.5%

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

 # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()

    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    print(layer3_weights.get_shape().as_list())
    print(reshape.get_shape().as_list())
    return tf.matmul(hidden, layer4_weights) + layer4_biases

  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [784, 64]
# [16, 784]
# [784, 64]
# [10000, 784]
# [784, 64]
# [10000, 784]

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.114902
# Minibatch accuracy: 18.8%
# Validation accuracy: 12.2%
# Minibatch loss at step 50: 2.170438
# Minibatch accuracy: 12.5%
# Validation accuracy: 23.9%
# Minibatch loss at step 100: 1.570393
# Minibatch accuracy: 37.5%
# Validation accuracy: 47.9%
# Minibatch loss at step 150: 0.851121
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.5%
# Minibatch loss at step 200: 0.860175
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 250: 1.314378
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.1%
# Minibatch loss at step 300: 0.419816
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 350: 0.520863
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 400: 0.390069
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.865531
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.774967
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 0.818120
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 600: 0.318624
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 650: 1.078362
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 700: 0.948379
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 750: 0.079129
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 800: 0.607957
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 850: 1.014188
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.611891
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 950: 0.506989
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 1000: 0.258454
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Test accuracy: 90.2%

# %%
#implementation of lenet 5 archetecture
batch_size = 16
patch_size = 5
num_hidden = 120

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, 6], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([6]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, 6, 16], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[16]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [256, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

 # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    print(pool.get_shape().as_list())
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    
    shape = pool.get_shape().as_list()
    print(shape)

    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases

  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [16, 14, 14, 6]
# [16, 4, 4, 16]
# [10000, 14, 14, 6]
# [10000, 4, 4, 16]
# [10000, 14, 14, 6]
# [10000, 4, 4, 16]

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.948385
# Minibatch accuracy: 6.2%
# Validation accuracy: 9.6%
# Minibatch loss at step 50: 2.203604
# Minibatch accuracy: 12.5%
# Validation accuracy: 37.2%
# Minibatch loss at step 100: 1.216413
# Minibatch accuracy: 68.8%
# Validation accuracy: 55.5%
# Minibatch loss at step 150: 0.693420
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 200: 1.211154
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 250: 1.185697
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 0.310423
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 350: 0.599968
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 400: 0.309313
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.773245
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 500: 0.772483
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 550: 0.809032
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.363225
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 650: 0.864640
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.920699
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 750: 0.032752
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.636042
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 850: 0.846732
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 900: 0.699162
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 950: 0.604693
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.299265
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Test accuracy: 90.5%
